# %%
# 02_exploratory_data.ipynb

import pandas as pd
import sys
import os
sys.path.append('../scripts')

data = pd.read_csv('../data/cleaned_data/cleaned_data.csv')

data
# Out:
#         Countries     2000     2001     2002     2003     2004     2005  \
# 0           China   299276   303256   311193   335649   335393   209477
# 1          France   337326   324413   325981   324997   369796   366402
# 2         Germany   975753  1026310   991695  1099140  1170880  1180240
# 3           Italy   329708   368761   407814   453088   472755   470487
# 4           Japan   941611   796094   848330   899215   971488   989418
# 5        Portugal   188701   170378   168535   186494   200367   225242
# 6           Spain   146529   160822   175115   168244   235154   228322
# 7  United Kingdom   171298   225323   162782   140942   124931    91875
# 8   United States  1581350  1240320  1547450  1279400  1548730  1870400
#
#       2006     2007     2008  ...     2014     2015     2016     2017  \
# 0   222095   170772   138460  ...    85998    70777    68647    69957
# 1   394956   443775   395784  ...   384952   364321   417895   400150
# ...

# %%
from eda import graph_animated, import_evolution, country_graph, linear_regression

graph_animated(data)

#Aluminium Importation over the years in some countries

# %% [markdown]
# <img src="country_data.gif" width="900">

# %%
import_evolution(data, 'Japan')

#Aluminium Importation graphic in a chosen country

# %%
country_graph(data, 'Japan')
# Out:
#     Year  Quantity
# 0   2000    941611
# 1   2001    796094
# 2   2002    848330
# 3   2003    899215
# 4   2004    971488
# 5   2005    989418
# 6   2006   1137420
# 7   2007   1128710
# 8   2008   1169440
# 9   2009    621830
# 10  2010   1020100
# 11  2011   1070750
# 12  2012   1103830
# 13  2013   1014240
# 14  2014   1125460
# 15  2015   1070040
# 16  2016   1102930
# 17  2017   1192885
# 18  2018   1282840
# 19  2019   1082738
# 20  2020    882636
# 21  2021   1134670
# 22  2022   1055750
# 23  2023   1077760

# %%
linear_regression(data, 'Japan')

#predicting the aluminium importation in 2035 using the linear regression model
# Out:
# R2 Score: 0.21

# %%
import pandas as pd
import sys
sys.path.append('../scripts')

df = pd.read_csv('../data/cleaned_data.csv')
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  \
# ...

# %% [markdown]
# ### Verifying total sales for each month

# %%
from eda import get_total_sales, plot_sales_per_month, plot_sales_per_city, plot_sales_time, plot_quantity_per_product, plot_quantity_price_per_product

# %%
df = get_total_sales(df)
# Out:
#        Quantity Ordered       Sales
# Month
# 1                 10903  1822256.73
# 2                 13449  2202022.42
# 3                 17005  2807100.38
# 4                 20558  3390670.24
# 5                 18667  3152606.75
# 6                 15253  2577802.26
# 7                 16072  2647775.76
# 8                 13448  2244467.88
# 9                 13109  2097560.13
# 10                22703  3736726.88
# 11                19798  3199603.20
# 12                28114  4613443.34

# %% [markdown]
# ### December is the month with the most Sales

# %%
plot_sales_per_month(df)

# %% [markdown]
# ### Most sales has been made in San Francisco

# %%
plot_sales_per_city(df)

# %% [markdown]
# ### According to the next graphic around 11h and around 19h are the best time to advertise the products

# %%
plot_sales_time(df)

# %% [markdown]
# ### In terms in quantity, batteries are the most popular product

# %%
plot_quantity_per_product(df)

# %% [markdown]
# ### Here we can see the relationship between the quantity sold with its price
#
# Obeservations:
# - Is noticeble there's an inverse relationship between price and quantity ordered for many products.
# - There are significant variations in quantities across products.
# - Some products show very high order levels (>25,000 units). Others maintain minimal quantities (<5,000 units).
# - Most sales happens around October-December probable because christmas and christmas eve, and around April and May.
# - San Francisco shows the highest sales, Los Angeles and New York follow with significant sales and Portland has the lowest sales.
#
# Recommendations:
# - Review products with very high quantities to prevent overstock, implementing better inventory management for products with extreme quantities.
# - Analyze the pricing strategy for products with very high prices but low quantities. Test the price elasticity of demand to determine if the pricing strategy is effective.
# - Consider discontinuing or reducing focus on products/models with both low quantities and low prices if they're not profitable.
# - Evaluate if high-priced items with low quantities are luxury/specialty items that justify their positioning.
# - Prioritize stock allocation to high-performing cities like San Francisco.
# - Optimize delivery routes and warehouse locations based on sales volumes.
# - Analyse the causes and develop a growth plans for underperforming cities.
# - During the high demand season, could be a good time to advertise the products specially around 11:00 am and 7:00 pm.

# %%
plot_quantity_price_per_product(df)
